# %% [markdown]
# # This file involves code for training a Random Forest Model on the MNIST Data which would be used while extracting the number from the videos

# %% [markdown]
# -> Importing the Necessary Libraries:

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# -> Reading the MNIST Data

# %%
df = pd.read_csv("/content/drive/MyDrive/Trisem 3/PR and ML/Mini Project/mnist_train.csv")

# %% [markdown]
# -> Shuffling the Data

# %%
df = df.sample(frac = 1)

# %% [markdown]
# -> Creating Feature and Label Arrays

# %%
X = df[[i for i in df.columns[1:]]].values
Y = df[df.columns[0]].values.ravel()

# %% [markdown]
# -> Creating the Training and Testing Datasets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3)

# %% [markdown]
# -> Creating the Random Forest Model:

# %% [markdown]
# -> We experimented on various values for n_estimators and concluded that 1000 was giving best results:

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_estimators=1000)

# %% [markdown]
# -> Training the Model:

# %%
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# -> Making Predictions on the Test Data:

# %%
Y_pred = rf.predict(X_test)

# %% [markdown]
# -> Evaluating the Predictions:

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Y_test,Y_pred)
# Out:
# 0.9690555555555556

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(Y_test,Y_pred)
# Out:
# array([[1757,    1,    2,    0,    2,    2,    7,    0,   11,    1],
#        [   0, 2014,   12,    5,    4,    0,    1,    7,    1,    1],
#        [   9,    4, 1740,    8,    6,    0,    7,   14,   10,    2],
#        [   4,    0,   26, 1751,    1,   14,    1,   10,   14,    8],
#        [   1,    2,    3,    0, 1682,    0,   12,    2,    4,   25],
#        [   9,    2,    4,   15,    2, 1560,   14,    1,    9,    7],
#        [   4,    2,    1,    0,    4,   15, 1777,    0,    6,    0],
#        [   1,    6,   20,    1,    8,    0,    0, 1797,    4,   19],
#        [   3,   11,    3,    9,    5,    8,    6,    2, 1717,   20],
#        [   9,    4,    4,   25,   21,    4,    1,   15,    9, 1648]])

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1783
#            1       0.98      0.98      0.98      2045
#            2       0.96      0.97      0.96      1800
#            3       0.97      0.96      0.96      1829
#            4       0.97      0.97      0.97      1731
#            5       0.97      0.96      0.97      1623
#            6       0.97      0.98      0.98      1809
#            7       0.97      0.97      0.97      1856
#            8       0.96      0.96      0.96      1784
#            9       0.95      0.95      0.95      1740
#
#     accuracy                           0.97     18000
#    macro avg       0.97      0.97      0.97     18000
# weighted avg       0.97      0.97      0.97     18000

# %% [markdown]
# -> Saving the Model:

# %%
joblib.dump(rf,"/content/drive/MyDrive/Trisem 3/PR and ML/Mini Project/RF.joblib")

# %% [markdown]
# # In this File we have created our first classifier for the Project - Random Forest. We coded training of the Model and wrote the code for its evaluation.
