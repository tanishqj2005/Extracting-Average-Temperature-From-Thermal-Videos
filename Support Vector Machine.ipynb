# %% [markdown]
# # This file involves code for training a Support Vector Machine Model on the MNIST Data which would be used while extracting the number from the videos

# %% [markdown]
# -> Importing the Necessary Libraries:

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.svm import SVC

# %% [markdown]
# -> Reading the MNIST Data

# %%
df = pd.read_csv("/content/drive/MyDrive/Trisem 3/PR and ML/Mini Project/mnist_train.csv")

# %% [markdown]
# -> Shuffling the Data

# %%
df = df.sample(frac = 1)

# %% [markdown]
# -> Creating Feature and Label Arrays

# %%
X = df[[i for i in df.columns[1:]]].values
Y = df[df.columns[0]].values.ravel()

# %% [markdown]
# -> Creating the Training and Testing Datasets:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3)

# %% [markdown]
# -> Creating the Support Vector Machine Model:

# %% [markdown]
# -> We experimented on various values for 'C' and concluded that 100 was giving best results with a Gaussian Kernel:

# %%
clf=SVC(C=100,kernel='rbf')

# %% [markdown]
# -> Training the Model:

# %%
clf.fit(X_train,Y_train)
# Out:
# SVC(C=100, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %% [markdown]
# -> Making Predictions on the Test Data:

# %%
Y_pred = clf.predict(X_test)

# %% [markdown]
# -> Evaluating the Predictions:

# %%
from sklearn.metrics import accuracy_score

accuracy_score(Y_test,Y_pred)
# Out:
# 0.9835555555555555

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(Y_test,Y_pred)
# Out:
# array([[1804,    0,    1,    0,    1,    3,    1,    1,    2,    1],
#        [   0, 1991,    5,    1,    1,    0,    0,    3,    1,    1],
#        [   6,    0, 1813,    3,    1,    0,    4,    7,    4,    2],
#        [   0,    1,    6, 1775,    1,   14,    0,    3,    5,    5],
#        [   0,    6,    5,    0, 1696,    1,    3,    3,    1,   12],
#        [   0,    1,    2,    9,    2, 1565,    6,    0,    2,    8],
#        [  10,    2,    1,    0,    4,    4, 1765,    0,    3,    0],
#        [   1,    8,   11,    2,    7,    1,    0, 1850,    2,   10],
#        [   2,    2,    3,    8,    6,   11,    1,    1, 1717,    3],
#        [   6,    3,    3,    7,    9,    4,    0,   11,    5, 1728]])

# %%
from sklearn.metrics import classification_report

print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1814
#            1       0.99      0.99      0.99      2003
#            2       0.98      0.99      0.98      1840
#            3       0.98      0.98      0.98      1810
#            4       0.98      0.98      0.98      1727
#            5       0.98      0.98      0.98      1595
#            6       0.99      0.99      0.99      1789
#            7       0.98      0.98      0.98      1892
#            8       0.99      0.98      0.98      1754
#            9       0.98      0.97      0.97      1776
#
#     accuracy                           0.98     18000
#    macro avg       0.98      0.98      0.98     18000
# weighted avg       0.98      0.98      0.98     18000

# %% [markdown]
# -> Saving the Model:

# %%
joblib.dump(clf,"/content/drive/MyDrive/Trisem 3/PR and ML/Mini Project/SVM.joblib")

# %% [markdown]
# # In this File we have created our second classifier for the Project - Support Vector Machine. We coded training of the Model and wrote the code for its evaluation.
